# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/mnt/f/codes/robust_motor/data/Temperature/train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df = pd.read_csv('/mnt/f/codes/robust_motor/data/Temperature/train.csv')
#
# File /data-nfs/sagar/anaconda3/envs/rm/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df

# %%
df = pd.read_csv('/mnt/f/codes/robust_motor/data/Temperature/val.csv')

# %%
df17 = df[df['profile_id'] == 17]

# %%
df
# Out:
#        Unnamed: 0         u_q    coolant  stator_winding        u_d  \
# 0          984807   -1.887356  30.721162       32.113178   1.946434
# 1          984808    0.604919  30.721209       32.115623   0.109622
# 2          984809    4.665253  30.721242       32.122736  -6.753488
# 3          984810    9.206368  30.721266       32.130268 -16.699363
# 4          984811   14.197583  30.720804       32.117775 -28.559625
# ...           ...         ...        ...             ...        ...
# 88772     1307710  116.028043  27.481724       72.121731 -60.904704
# 88773     1307711  116.049104  27.462331       72.119607 -60.818504
# 88774     1307712  116.078629  27.385514       72.117085 -60.778468
# 88775     1307713  116.074434  27.288885       72.115738 -60.779719
# 88776     1307714  116.090811  27.161841       72.114737 -60.845847
#
#        stator_tooth  motor_speed         i_d         i_q         pm  \
# 0         31.291477     0.022686   -2.001102    1.098022  37.112483
# ...

# %%
time = np.arange(0, df17.shape[0] * 1/20, 1/20)

# %%
plt.plot(time, df17['u_q'])
