# %%
from scipy.io import loadmat

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data = loadmat('/mnt/h/FaultDetection/datasets/CWR/3002.mat')

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X057_DE_time'])

# %%
data['X100_DE_time'].shape, data['X100_FE_time'].shape, data['X100RPM'][0]
# Out:
# ((485643, 1), (485643, 1), array([1725], dtype=uint16))

# %%
plt.plot(data['X098_DE_time'][:100])
plt.plot(data['X098_FE_time'][:100])
plt.plot(data['X099_DE_time'][:100])
plt.plot(data['X099_FE_time'][:100])
